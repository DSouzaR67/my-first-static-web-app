# %%
# !pip install googlemaps gmplot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 164.7/164.7 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import googlemaps

# Tu clave de API de Google Maps
api_key = 'AIzaSyAZBPYol89oaQXB2RwIHpIanDSpEH0NXNo'

# Inicializa el cliente de Google Maps
gmaps = googlemaps.Client(key=api_key)

# Lista de puntos geolocalizados
waypoints = [
    {'location': '20.7125399,-103.378585', 'stopover': True},  # Plaza Patria
    {'location': '20.6767223,-103.3478285', 'stopover': True},  # Centro de Guadalajara
    {'location': '20.6596988,-103.3496092', 'stopover': True},  # Tlaquepaque
]

# Define el punto de inicio y el punto final
origin = '20.7125399,-103.378585'  # Plaza Patria
destination = '20.6596988,-103.3496092'  # Tlaquepaque

# Usa gmaps.directions para calcular la ruta óptima
directions_result = gmaps.directions(
    origin=origin,
    destination=destination,
    waypoints=[wp['location'] for wp in waypoints],
    optimize_waypoints=True,
    mode="driving"
)

# Imprime el resultado
for step in directions_result[0]['legs'][0]['steps']:
    print(step['html_instructions'])

# Imprime el orden optimizado de los waypoints
waypoint_order = directions_result[0]['waypoint_order']
optimized_waypoints = [waypoints[i] for i in waypoint_order]
print("Orden optimizado de los waypoints:")
for wp in optimized_waypoints:
    print(wp['location'])
# Out:
# Head
# Orden optimizado de los waypoints:
# 20.7125399,-103.378585
# 20.6767223,-103.3478285
# 20.6596988,-103.3496092

# %%
# Lista de direcciones
addresses = [
    'JALISCO, TLAJOMULCO DE ZUNIGA, BLVD VALLE DEL SILICIO 130 181 ,CP:45645',
    'JALISCO, ZAPOPAN, AV RIO BLANCO 1258 ,CP:45200',
    'JALISCO, GUADALAJARA, ISLA PANTENARIA 2055 .,CP:44950',
    'JALISCO, ZAPOPAN, AV LOS PINOS 423 6 ,CP:45120',
    'JALISCO, ZAPOPAN, C PASEO DE LOS ENCINOS 4 ,CP:45180',
    'JALISCO, ZAPOPAN, PROL BOYERO 3700 EDIF 1 DEP 202 ,CP:45070',
    'JALISCO, ZAPOPAN, AV DEL BOSQUE REAL 1507,CP:45134',
    'JALISCO, TLAJOMULCO DE ZUNIGA, AVENIDA CASA FUERTE 285 DEPTO 78,CP:45645',
    'JALISCO, ZAPOPAN, SAN ERNESTO 3705 ,CP:45040',
    'JALISCO, ZAPOPAN, P DE LAS HORTENCIAS 2551,CP:45238',
    'JALISCO, TLAJOMULCO DE ZUNIGA, VALLE DE LAS PALMAS 46 ,CP:45640'
]

# Geocodificar todas las direcciones
waypoints = []
for address in addresses:
    geocode_result = gmaps.geocode(address)
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        waypoints.append(f"{location['lat']},{location['lng']}")

# Define el punto de inicio y el punto final
origin = waypoints[0]  # Primer punto como origen
destination = waypoints[-1]  # Último punto como destino

# Usa gmaps.directions para calcular la ruta óptima
directions_result = gmaps.directions(
    origin=origin,
    destination=destination,
    waypoints=waypoints[1:-1],
    optimize_waypoints=True,
    mode="driving"
)

# Imprime las instrucciones paso a paso para la ruta optimizada
for step in directions_result[0]['legs'][0]['steps']:
    print(step['html_instructions'])

# Imprime el orden optimizado de los waypoints
waypoint_order = directions_result[0]['waypoint_order']
optimized_waypoints = [waypoints[i] for i in waypoint_order]
print("Orden optimizado de los waypoints:")
for wp in optimized_waypoints:
    print(wp)
# Out:
# Head <b>northeast</b> on <b>Calle Blvd. Valle del Silicio</b> toward <b>Valle de Gibraltar</b>
# Turn <b>left</b> onto <b>Av. La Tijera</b>
# Turn <b>right</b> onto <b>Acatlan de Juarez - Guadalajara</b>/<wbr/><b>Av. Adolfo López Mateos Sur</b>/<wbr/><b>Autopista Guadalajara - Colima</b>/<wbr/><b>Morelia-Guadalajara</b>/<wbr/><b>México 15</b>/<wbr/><b>México 54D</b>/<wbr/><b>México 80 E</b><div style="font-size:0.9em">Pass by Casther (on the right in 2.2 km)</div>
# Continue straight to stay on <b>Acatlan de Juarez - Guadalajara</b>/<wbr/><b>Av. Adolfo López Mateos Sur</b>/<wbr/><b>Autopista Guadalajara - Colima</b>/<wbr/><b>Morelia-Guadalajara</b>/<wbr/><b>México 15</b>/<wbr/><b>México 54D</b>/<wbr/><b>México 80 E</b><div style="font-size:0.9em">Continue to follow Acatlan de Juarez - Guadalajara/<wbr/>Av. Adolfo López Mateos Sur/<wbr/>Autopista Guadalajara - Colima/<wbr/>Morelia-Guadalajara/<wbr/>México 15/<wbr/>México 54D</div>
# ...

# %%
import googlemaps
from gmplot import gmplot

# %%
# Lista de direcciones
addresses = [
    'JALISCO ,ZAPOPAN ,AVE MADEIRAS 197 INT 43,CP 45134',
'JALISCO ,ZAPOPAN ,AV DEL BOSQUE 1507 INT 224,CP 45134',
'JALISCO ,ZAPOPAN ,AV RIO BLANCO 1258,CP 45200',
'JALISCO ,ZAPOPAN ,C PASEO DE LOS ENCINOS 4,CP 45180',
'JALISCO ,ZAPOPAN ,PIPILA 50 INT A ,CP 45186',
'JALISCO ,ZAPOPAN ,PROL BOYERO 3700 EDIF 1 DEPTO 202,CP 45070',
'JALISCO ,ZAPOPAN ,P DE LAS HORTENCIAS 2551,CP 45238',
'JALISCO ,ZAPOPAN ,RIO TUXPAN 1609,CP 45080',
'JALISCO ,ZAPOPAN ,SAN ERNESTO 3705 ,CP 45040',
'JALISCO ,ZAPOPAN ,SANTA TERESA DE JESUS 302,CP 45040',
'JALISCO ,ZAPOPAN ,AV DE LOS PINOS 423 INT 6,CP 45120',
'JALISCO ,ZAPOPAN ,MANUEL AVILA CAMACHO 8,CP 45160',
'JALISCO ,TLAJOMULCO DE ZUÑIGA,AVENIDA CASA FUERTE 285 DEPTO 78,CP 45645',
'JALISCO ,TLAJOMULCO DE ZUÑIGA,VALLE DE LAS PALMAS 46 ,CP 45640',
'JALISCO ,TLAJOMULCO DE ZUÑIGA,BLVD VALLE DEL SILICIO 130 INT 181,CP 45645',
'JALISCO ,TLAJOMULCO DE ZUÑIGA,AV SAN ALFONSO 118 INT 2,CP 45655',
'JALISCO ,GUADALAJARA ,ISLA PANTENARIA 2055,CP 44950',
'JALISCO ,ZAPOPAN ,SANTA BARBARA 11,CP 45236'

]

# Geocodificar todas las direcciones
locations = []
for address in addresses:
    geocode_result = gmaps.geocode(address)
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        locations.append(f"{location['lat']},{location['lng']}")

# Define el punto de inicio y el punto final
origin = locations[0]
destination = locations[-1]

# Usa gmaps.directions para calcular la ruta óptima
directions_result = gmaps.directions(
    origin=origin,
    destination=destination,
    waypoints=locations[1:-1],
    optimize_waypoints=True,
    mode="driving"
)

# Extrae los puntos de la ruta optimizada
route_points = []
for leg in directions_result[0]['legs']:
    for step in leg['steps']:
        start_location = step['start_location']
        end_location = step['end_location']
        route_points.append((start_location['lat'], start_location['lng']))
        route_points.append((end_location['lat'], end_location['lng']))

# Crear el mapa usando gmplot
gmap = gmplot.GoogleMapPlotter(
    route_points[0][0], route_points[0][1], 13, apikey=api_key
)

# Trazar la ruta optimizada en el mapa
lats, lngs = zip(*route_points)
gmap.plot(lats, lngs, 'blue', edge_width=2.5)

# Guardar el mapa en un archivo HTML
gmap.draw("d:\optimized_route_map.html")

print("Mapa guardado como optimized_route_map.html")
# Out:
# Mapa guardado como optimized_route_map.html

# %%
# Lista de direcciones
addresses = []
addresses = [
    'JALISCO, TLAJOMULCO DE ZUNIGA, BLVD VALLE DEL SILICIO 130 181 ,CP:45645',
    'JALISCO, ZAPOPAN, AV RIO BLANCO 1258 ,CP:45200',
    'JALISCO, GUADALAJARA, ISLA PANTENARIA 2055 .,CP:44950',
    'JALISCO, ZAPOPAN, AV LOS PINOS 423 6 ,CP:45120',
    'JALISCO, ZAPOPAN, C PASEO DE LOS ENCINOS 4 ,CP:45180',
    'JALISCO, ZAPOPAN, PROL BOYERO 3700 EDIF 1 DEP 202 ,CP:45070',
    'JALISCO, ZAPOPAN, AV DEL BOSQUE REAL 1507,CP:45134',
    'JALISCO, TLAJOMULCO DE ZUNIGA, AVENIDA CASA FUERTE 285 DEPTO 78,CP:45645',
    'JALISCO, ZAPOPAN, SAN ERNESTO 3705 ,CP:45040',
    'JALISCO, ZAPOPAN, P DE LAS HORTENCIAS 2551,CP:45238',
    'JALISCO, TLAJOMULCO DE ZUNIGA, VALLE DE LAS PALMAS 46 ,CP:45640'
]

# Geocodificar todas las direcciones
locations = []
for address in addresses:
    geocode_result = gmaps.geocode(address)
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        locations.append(f"{location['lat']},{location['lng']}")

# Define el punto de inicio y el punto final
origin = locations[0]
destination = locations[-1]

# Usa gmaps.directions para calcular la ruta óptima
directions_result = gmaps.directions(
    origin=origin,
    destination=destination,
    waypoints=locations[1:-1],
    optimize_waypoints=True,
    mode="driving"
)

# Extrae los puntos de la ruta optimizada
route_points = []
for leg in directions_result[0]['legs']:
    for step in leg['steps']:
        start_location = step['start_location']
        end_location = step['end_location']
        route_points.append((start_location['lat'], start_location['lng']))
        route_points.append((end_location['lat'], end_location['lng']))

# Crear el mapa usando gmplot
gmap = gmplot.GoogleMapPlotter(
    route_points[0][0], route_points[0][1], 13, apikey=api_key
)

# Trazar la ruta optimizada en el mapa
gmap.plot(*zip(*route_points), 'blue', edge_width=2.5)

# Agregar marcadores en cada punto de la ruta
for lat, lng in route_points:
    gmap.marker(lat, lng)

# Guardar el mapa en un archivo HTML
gmap.draw("d:\optimized_route_mapjj.html")

print("Mapa guardado como optimized_route_mapJJ.html")
# Out:
# Mapa guardado como optimized_route_mapJJ.html

# %%
# Lista de direcciones
addresses = ['Platino 2860, Verde Valle, 44550 Guadalajara, Jal.',
    'JALISCO ,ZAPOPAN ,AVE MADEIRAS 197 INT 43,CP 45134',
'JALISCO ,ZAPOPAN ,AV DEL BOSQUE 1507 INT 224,CP 45134',
'JALISCO ,ZAPOPAN ,AV RIO BLANCO 1258,CP 45200',
'JALISCO ,ZAPOPAN ,C PASEO DE LOS ENCINOS 4,CP 45180',
'JALISCO ,ZAPOPAN ,PIPILA 50 INT A ,CP 45186',
'JALISCO ,ZAPOPAN ,PROL BOYERO 3700 EDIF 1 DEPTO 202,CP 45070',
'JALISCO ,ZAPOPAN ,P DE LAS HORTENCIAS 2551,CP 45238',
'JALISCO ,ZAPOPAN ,RIO TUXPAN 1609,CP 45080',
'JALISCO ,ZAPOPAN ,SAN ERNESTO 3705 ,CP 45040',
'JALISCO ,ZAPOPAN ,SANTA TERESA DE JESUS 302,CP 45040',
'JALISCO ,ZAPOPAN ,AV DE LOS PINOS 423 INT 6,CP 45120',
'JALISCO ,ZAPOPAN ,MANUEL AVILA CAMACHO 8,CP 45160',
'JALISCO ,TLAJOMULCO DE ZUÑIGA,AVENIDA CASA FUERTE 285 DEPTO 78,CP 45645',
'JALISCO ,TLAJOMULCO DE ZUÑIGA,VALLE DE LAS PALMAS 46 ,CP 45640',
'JALISCO ,TLAJOMULCO DE ZUÑIGA,BLVD VALLE DEL SILICIO 130 INT 181,CP 45645',
'JALISCO ,TLAJOMULCO DE ZUÑIGA,AV SAN ALFONSO 118 INT 2,CP 45655',
'JALISCO ,GUADALAJARA ,ISLA PANTENARIA 2055,CP 44950',
'JALISCO ,ZAPOPAN ,SANTA BARBARA 11,CP 45236'
]

# Geocodificar todas las direcciones
locations = []
for address in addresses:
    geocode_result = gmaps.geocode(address)
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        locations.append(f"{location['lat']},{location['lng']}")

# Define el punto de inicio y el punto final
origin = locations[0]
destination = locations[-1]

# Usa gmaps.directions para calcular la ruta óptima
directions_result = gmaps.directions(
    origin=origin,
    destination=destination,
    waypoints=locations[1:-1],
    optimize_waypoints=True,
    mode="driving"
)

# Extrae los puntos de la ruta optimizada
route_points = []
for leg in directions_result[0]['legs']:
    for step in leg['steps']:
        start_location = step['start_location']
        end_location = step['end_location']
        route_points.append((start_location['lat'], start_location['lng']))
        route_points.append((end_location['lat'], end_location['lng']))

# Crear el mapa usando gmplot
gmap = gmplot.GoogleMapPlotter(
    route_points[0][0], route_points[0][1], 13, apikey=api_key
)

# Trazar la ruta optimizada en el mapa
gmap.plot(*zip(*route_points), 'blue', edge_width=2.5)

# Agregar marcadores solo en los puntos de inicio y fin de cada paso en la ruta
for leg in directions_result[0]['legs']:
    start_location = leg['start_location']
    end_location = leg['end_location']
    gmap.marker(start_location['lat'], start_location['lng'])
    gmap.marker(end_location['lat'], end_location['lng'])

# Guardar el mapa en un archivo HTML
gmap.draw("d:\optimized_route_mapjj3.html")

print("Mapa guardado como optimized_route_map.html")
# Out:
# Mapa guardado como optimized_route_map.html
